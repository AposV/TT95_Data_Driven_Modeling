# %% [markdown]
# <h1>Data Preparation</h1>
# This notebook downloads the sensor data from the server, selects data withiin specific date ranges, resamples data at specified time intervals and joins all processed sensor data in a single dataframe which can then be exported as a single csv file that will be used as inputs in other modules

# %%
import pandas as pd
import mysql.connector as sqlcn
import numpy as np
import matplotlib.pyplot as plt

import help_funcs.data_handlers as dh

plt.style.use('ggplot')
plt.rcParams["figure.figsize"] = (18,14)

# %%
# Download data from database for each sensor and save each one in a dictionary
raw_data = dh.download_data()
# Out:
# C:\Users\vasil\miniconda3\envs\mlenv\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# C:\Users\vasil\miniconda3\envs\mlenv\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# C:\Users\vasil\miniconda3\envs\mlenv\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# C:\Users\vasil\miniconda3\envs\mlenv\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# C:\Users\vasil\miniconda3\envs\mlenv\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# C:\Users\vasil\miniconda3\envs\mlenv\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# C:\Users\vasil\miniconda3\envs\mlenv\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
# For the YP extensometers calculate the aperture change for each time step
# This is needed to be consistent when resampling and avoid introducing
# drifts in apperture when resampling
raw_data['ext1']['aprtr_change'] = raw_data['ext1']['apperture'].diff()
raw_data['ext2']['aprtr_change'] = raw_data['ext2']['apperture'].diff()

# %%
data_2019 = dh.select_date_range(start_date='2022-09-01', df_dict=raw_data)
resmpl_2019 = dh.resample_dfs(data_2019, '1h', dh.resampling_rules)
joined = dh.join_data(resmpl_2019, exclude='arduino')
# Out:
# ['ext1', 'ext2', 'rta', 'libelium', 'arduino']

# %%
#joined.to_csv('./Prepared Datasets/Mar2019Aug2019rs1h.csv')
joined
# Out:
#                      air_temp_ext1  apperture_ext1  aprtr_change_ext1  \
# datetime
# 2022-09-01 00:00:00      32.800000     4842.000000                0.0
# 2022-09-01 01:00:00      32.800000     4842.000000                0.0
# 2022-09-01 02:00:00      32.800000     4842.000000                0.0
# 2022-09-01 03:00:00      32.750000     4841.833333                0.0
# 2022-09-01 04:00:00      32.716667     4841.666667                0.0
# ...                            ...             ...                ...
# 2022-11-07 16:00:00      30.300000     4896.333333               -1.0
# 2022-11-07 17:00:00      30.300000     4896.000000                0.0
# 2022-11-07 18:00:00      30.266667     4896.000000                0.0
# 2022-11-07 19:00:00      30.200000     4895.500000               -1.0
# 2022-11-07 20:00:00      30.183333     4895.833333                1.0
#
#                      air_temp_ext2  apperture_ext2  aprtr_change_ext2  \
# datetime
# 2022-09-01 00:00:00         32.299     3941.666667                1.0
# 2022-09-01 01:00:00         32.299     3942.000000                1.0
# 2022-09-01 02:00:00         32.299     3943.166667                0.0
# 2022-09-01 03:00:00         32.299     3944.666667                3.0
# 2022-09-01 04:00:00         32.299     3945.833333               -1.0
# ...                            ...             ...                ...
# 2022-11-07 16:00:00         30.100     4075.000000                0.0
# 2022-11-07 17:00:00         30.100     4075.000000                0.0
# 2022-11-07 18:00:00         30.100     4075.000000                0.0
# 2022-11-07 19:00:00         30.050     4075.000000                0.0
# 2022-11-07 20:00:00         30.000     4075.000000                0.0
#
#                         t1_rta     t2_rta     t3_rta     t4_rta  ...  \
# datetime                                                         ...
# 2022-09-01 00:00:00  31.550000  32.299000  32.400000  32.400000  ...
# 2022-09-01 01:00:00  31.500000  32.299000  32.433333  32.400000  ...
# 2022-09-01 02:00:00  31.500000  32.299000  32.416667  32.400000  ...
# 2022-09-01 03:00:00  31.500000  32.266000  32.400000  32.400000  ...
# 2022-09-01 04:00:00  31.500000  32.266000  32.400000  32.383167  ...
# ...                        ...        ...        ...        ...  ...
# 2022-11-07 16:00:00  29.500000  29.733333  29.800000  29.800000  ...
# 2022-11-07 17:00:00  29.500000  29.700000  29.800000  29.800000  ...
# 2022-11-07 18:00:00  29.500000  29.700000  29.783333  29.800000  ...
# 2022-11-07 19:00:00  29.500000  29.600000  29.750000  29.800000  ...
# 2022-11-07 20:00:00  29.466667  29.600000  29.683333  29.800000  ...
#
#                         t9_rta    t11_rta  epoch_time_libelium  \
# datetime
# 2022-09-01 00:00:00  33.000000  32.433333         1.661996e+09
# 2022-09-01 01:00:00  33.000000  32.416667         1.661999e+09
# 2022-09-01 02:00:00  33.000000  32.400000         1.662003e+09
# 2022-09-01 03:00:00  33.000000  32.400000         1.662006e+09
# 2022-09-01 04:00:00  32.933333  32.400000         1.662010e+09
# ...                        ...        ...                  ...
# 2022-11-07 16:00:00  30.300000  31.433333         1.667845e+09
# 2022-11-07 17:00:00  30.300000  31.366667         1.667849e+09
# 2022-11-07 18:00:00  30.250000  31.333333         1.667853e+09
# 2022-11-07 19:00:00  30.216667  31.316667         1.667856e+09
# 2022-11-07 20:00:00  30.200000  31.283333         1.667860e+09
#
#                      battery_level_libelium  dendrometer_libelium  \
# datetime
# 2022-09-01 00:00:00               93.000000                   5.0
# 2022-09-01 01:00:00               93.000000                   5.0
# 2022-09-01 02:00:00               93.000000                   5.0
# 2022-09-01 03:00:00               93.000000                   5.0
# 2022-09-01 04:00:00               92.333333                   5.0
# ...                                     ...                   ...
# 2022-11-07 16:00:00               98.000000                   5.0
# 2022-11-07 17:00:00               98.000000                   5.0
# 2022-11-07 18:00:00               98.000000                   5.0
# 2022-11-07 19:00:00               98.000000                   5.0
# 2022-11-07 20:00:00               98.000000                   5.0
#
#                      t1_libelium  r_humid_libelium  atm_p_libelium  \
# datetime
# 2022-09-01 00:00:00         32.0         35.666667            99.0
# 2022-09-01 01:00:00         32.0         35.166667            99.0
# 2022-09-01 02:00:00         32.0         35.000000            99.0
# 2022-09-01 03:00:00         32.0         35.333333            99.0
# 2022-09-01 04:00:00         32.0         35.166667            99.0
# ...                          ...               ...             ...
# 2022-11-07 16:00:00         30.0         25.166667           100.0
# 2022-11-07 17:00:00         30.0         25.166667           100.0
# 2022-11-07 18:00:00         30.0         25.000000           100.0
# 2022-11-07 19:00:00         30.0         25.000000           100.0
# 2022-11-07 20:00:00         30.0         25.000000           100.0
#
#                      t2_libelium  voltage_libelium
# datetime
# 2022-09-01 00:00:00         33.0               4.0
# 2022-09-01 01:00:00         33.0               4.0
# 2022-09-01 02:00:00         33.0               4.0
# 2022-09-01 03:00:00         33.0               4.0
# 2022-09-01 04:00:00         33.0               4.0
# ...                          ...               ...
# 2022-11-07 16:00:00         31.0               4.0
# 2022-11-07 17:00:00         31.0               4.0
# 2022-11-07 18:00:00         31.0               4.0
# 2022-11-07 19:00:00         31.0               4.0
# 2022-11-07 20:00:00         31.0               4.0
#
# [1629 rows x 24 columns]

# %%
joined.loc[:, ['air_temp_ext1', 'apperture_ext1']].plot(secondary_y=['apperture_ext1'])
joined.loc[:, ['air_temp_ext2', 'apperture_ext2']].plot(secondary_y=['apperture_ext2'])
#joined.plot()

#joined.loc[:, ['apperture_ext1']].plot()
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
raw_data['ext1'].sort_index().loc['2022-08-27':,['apperture', 'air_temp']].plot(secondary_y='air_temp')
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
ard.resample('1d').mean()['t1'].plot()
# Out:
# <AxesSubplot:xlabel='datetime'>
