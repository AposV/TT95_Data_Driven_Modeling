# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import scipy.signal as signal
import matplotlib.dates as mdates

plt.style.use('bmh')
plt.rcParams["figure.figsize"] = (18,6)
plt.rcParams['figure.titlesize'] = 24
plt.rcParams['axes.titlesize'] = 24
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 16
plt.rcParams['ytick.labelsize'] = 16
plt.rcParams['legend.fontsize'] = 14

# %%
data = pd.read_csv('Prepared Datasets/Aug2022Dec2022rs1h.csv')
data.datetime = pd.to_datetime(data.datetime)
data.set_index('datetime', inplace=True)
data.columns
# Out:
# Index(['air_temp_ext1', 'apperture_ext1', 'aprtr_change_ext1', 'air_temp_ext2',
#        'apperture_ext2', 'aprtr_change_ext2', 't1_rta', 't2_rta', 't3_rta',
#        't4_rta', 't5_rta', 't6_rta', 't7_rta', 't8_rta', 't9_rta', 't11_rta',
#        'epoch_time_libelium', 'battery_level_libelium', 'dendrometer_libelium',
#        'air_temp_libelium', 'r_humid_libelium', 'atm_p_libelium',
#        'rock_temp_libelium', 'voltage_libelium', 't1_arduino', 't2_arduino',
#        't3_arduino', 't4_arduino', 't5_arduino', 't6_arduino',
#        'luminosity_arduino'],
#       dtype='object')

# %%
# Column labels 
air_temp_c = [x for x in data.columns if x.__contains__('air_temp')]
rta_c = [x for x in data.columns if x.__contains__('rta')]
libelium_data_c = [x for x in data.columns if x.__contains__('libelium')]
arduino_data_c = [x for x in data.columns if x.__contains__('arduino')]

# %%
fig, axs = plt.subplots(3, 1, figsize=(22,22))

ax = axs[0]
ax.plot(data['air_temp_ext1'], label='YP Ext. 1')
ax.plot(data['air_temp_ext2'], label='YP Ext. 2')
ax.plot(data['air_temp_libelium'], label='Libelium Air Temp.', alpha=0.7)
ax.set_ylabel('Temperature (\N{degree sign}C)')
ax.legend()

ax = axs[1]
data.loc[:, 'luminosity_arduino'].plot(ax=ax)
ax.set_ylabel('Luminocity')

ax = axs[2]
data.loc[:,rta_c].plot(ax=ax)
# Out:
# <AxesSubplot:xlabel='datetime'>
